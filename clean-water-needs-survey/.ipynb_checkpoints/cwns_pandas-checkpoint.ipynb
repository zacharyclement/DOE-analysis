# %%
import pandas
import numpy as np
import matplotlib.pyplot as plt
import numpy as np

# %%
df_flow = pandas.read_csv('SUMMARY_FLOW.csv')
df_facility = pandas.read_csv('SUMMARY_FACILITY.csv')
df_sankey = pandas.read_csv('State_Sankey_www_flows.csv')

# %%
df_flow.head()
# Out:
#    CWNS_NUMBER  EXIST_MUNICIPAL  EXIST_INDUSTRIAL  EXIST_INFILTRATION  \
# 0   1000002001            0.060               NaN                 NaN
# 1   1000003001            2.500               0.3                 0.2
# 2   1000004001            4.700               NaN                 NaN
# 3   1000004002            1.510               NaN                 NaN
# 4   1000005001            0.017               NaN                 NaN
#
#    EXIST_TOTAL  EXIST_WET_WEATHER_PEAK  PRES_MUNICIPAL  PRES_INDUSTRIAL  \
# 0        0.060                     NaN           0.110              NaN
# 1        3.000                     NaN           7.600              NaN
# 2        4.700                     NaN           8.500              NaN
# 3        1.510                     NaN           1.950              NaN
# 4        0.017                   0.287           0.016              NaN
#
#    PRES_INFILTRATION  PRES_TOTAL  PRES_WET_WEATHER_PEAK  PROJ_MUNICIPAL  \
# 0                NaN       0.110                    NaN            0.11
# 1                NaN       7.600                    NaN            7.60
# 2                NaN       8.500                    NaN            8.50
# 3                NaN       1.950                    NaN            1.95
# 4                NaN       0.016                    NaN            0.07
#
#    PROJ_INDUSTRIAL  PROJ_INFILTRATION  PROJ_TOTAL  PROJ_WET_WEATHER_PEAK
# 0              NaN                NaN        0.11                    NaN
# 1              NaN                NaN        7.60                    NaN
# 2              NaN                NaN        8.50                    NaN
# 3              NaN                NaN        1.95                    NaN
# 4              NaN                NaN        0.07                    NaN

# %%
df_flow.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15359 entries, 0 to 15358
# Data columns (total 16 columns):
# CWNS_NUMBER               15359 non-null int64
# EXIST_MUNICIPAL           13534 non-null float64
# EXIST_INDUSTRIAL          2157 non-null float64
# EXIST_INFILTRATION        941 non-null float64
# EXIST_TOTAL               14613 non-null float64
# EXIST_WET_WEATHER_PEAK    1063 non-null float64
# PRES_MUNICIPAL            13536 non-null float64
# PRES_INDUSTRIAL           2191 non-null float64
# PRES_INFILTRATION         598 non-null float64
# PRES_TOTAL                14613 non-null float64
# PRES_WET_WEATHER_PEAK     680 non-null float64
# PROJ_MUNICIPAL            14017 non-null float64
# PROJ_INDUSTRIAL           2311 non-null float64
# PROJ_INFILTRATION         621 non-null float64
# PROJ_TOTAL                15151 non-null float64
# PROJ_WET_WEATHER_PEAK     751 non-null float64
# dtypes: float64(15), int64(1)
# memory usage: 1.9 MB

# %%
df_facility.head()
# Out:
#    REGION STATE PRIMARY_COUNTY SECONDARY_COUNTIES  \
# 0       4    AL           Hale                NaN
# 1       4    AL         Shelby                NaN
# 2       4    AL     Tallapoosa                NaN
# 3       4    AL     Tallapoosa                NaN
# 4       4    AL         Etowah                NaN
#
#                              AUTHORITY POINT_OF_CONTACT_NAME  \
# 0                        Town of Akron        Stanley Hollie
# 1                    City of Alabaster           Glen McCord
# 2         ALEXANDER CITY SUGAR CK WWTP     Shelby Richardson
# 3  Alexander City Wastewater Treatment     Shelby Richardson
# 4          Altoona Water & Sewer Board       Nate Livingston
#
#   POINT_OF_CONTACT_STREET_1 POINT_OF_CONTACT_STREET_2 POINT_OF_CONTACT_CITY  \
# 0               P. O. Box 8                       NaN                 Akron
# 1      201 1st Street North                       NaN             ALABASTER
# 2         CITY OF ALEXANDER     2515 SUGAR CREEK ROAD        ALEXANDER CITY
# 3              P.O. Box 552                       NaN        Alexander City
# 4              P.O. Box 279          2844 Main Street               Altoona
#
#   POINT_OF_CONTACT_STATE               ...                MEASUREMENT_DATE  \
# 0                     AL               ...                             NaN
# 1                     AL               ...                             NaN
# 2                     AL               ...                             NaN
# 3                     AL               ...                             NaN
# 4                     AL               ...                             NaN
#
#   TRIBE_IND SPECIAL_PROGRAM_AREAS FACILITY_ID     REVIEW_STATUS  \
# 0         N                   NaN     1239395  Federal Accepted
# 1         N                   NaN     1101826  Federal Accepted
# 2         N                   NaN     1101827  Federal Accepted
# 3         N                   NaN     1101828  Federal Accepted
# 4         N                   NaN     1101831  Federal Accepted
#
#    SMALL_COMMUNITY_IND POTW_PRESENT_IND  POTW_PROJECTED_IND  \
# 0                    Y                Y                   Y
# 1                    N                Y                   Y
# 2                    N                Y                   Y
# 3                    N                Y                   Y
# 4                    Y                Y                   Y
#
#   DECENTRALIZED_ONLY_IND                     CITIES_TOWNS
# 0                      N                              NaN
# 1                      N  Alabaster, Unincorporated areas
# 2                      N                              NaN
# 3                      N                              NaN
# 4                      N    Altoona, Unincorporated areas
#
# [5 rows x 59 columns]

# %%
df_facility.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27016 entries, 0 to 27015
# Data columns (total 59 columns):
# REGION                            27016 non-null int64
# STATE                             27016 non-null object
# PRIMARY_COUNTY                    27016 non-null object
# SECONDARY_COUNTIES                481 non-null object
# AUTHORITY                         27016 non-null object
# POINT_OF_CONTACT_NAME             10214 non-null object
# POINT_OF_CONTACT_STREET_1         11639 non-null object
# POINT_OF_CONTACT_STREET_2         2934 non-null object
# POINT_OF_CONTACT_CITY             11965 non-null object
# POINT_OF_CONTACT_STATE            27016 non-null object
# POINT_OF_CONTACT_ZIP              11662 non-null object
# POINT_OF_CONTACT_PHONE            11528 non-null object
# POINT_OF_CONTACT_FAX              4699 non-null object
# POINT_OF_CONTACT_EMAIL            4546 non-null object
# FACILITY_NAME                     27016 non-null object
# CWNS_NUMBER                       27016 non-null int64
# OWNER_TYPE                        27016 non-null object
# PRIMARY_WATERSHED_HUC             27016 non-null int64
# PRIMARY_WATERSHED_NAME            27016 non-null object
# SECONDARY_WATERSHEDS              451 non-null object
# PRIMARY_CONGRESSIONAL_DISTRICT    26998 non-null object
# SECONDARY_CONGRESSIONAL_DIST      903 non-null object
# NPDES_PERMIT_NUMBER               13613 non-null object
# PERMIT_TYPE                       13613 non-null object
# FACILITY_STREET_1                 16841 non-null object
# FACILITY_STREET_2                 3455 non-null object
# FACILITY_CITY                     16860 non-null object
# FACILITY_STATE                    17042 non-null object
# FACILITY_ZIP                      16715 non-null object
# SYSTEM_NAME                       2956 non-null object
# FACILITY_DESCRIPTION              2656 non-null object
# MILITARY_IND                      27016 non-null object
# TMDL_IND                          27016 non-null object
# SOURCE_WATER_PROTECTION_IND       27016 non-null object
# SMALL_COMMUNITY_EXCEPTION_IND     27016 non-null object
# PRES_FACILITY_TYPE                26105 non-null object
# PRES_FACILITY_OVERALL_TYPE        26105 non-null object
# PRES_TREATMENT_PLANT_TYPE         9701 non-null object
# PROJ_FACILITY_TYPE                26995 non-null object
# PROJ_FACILITY_OVERALL_TYPE        26995 non-null object
# PROJ_TREATMENT_PLANT_TYPE         9701 non-null object
# COORDINATE_TYPE                   21698 non-null object
# LOCATION_DESCRIPTION              20709 non-null object
# LATITUDE                          21698 non-null object
# LONGITUDE                         21698 non-null object
# HORIZONTAL_COORDINATE_DATUM       21537 non-null object
# HORIZONTAL_COLLECTION_METHOD      20612 non-null object
# SCALE                             4733 non-null object
# GEOGRAPHIC_LOCATION_SOURCE        21698 non-null object
# MEASUREMENT_DATE                  8246 non-null object
# TRIBE_IND                         27016 non-null object
# SPECIAL_PROGRAM_AREAS             946 non-null object
# FACILITY_ID                       27016 non-null int64
# REVIEW_STATUS                     27016 non-null object
# SMALL_COMMUNITY_IND               27016 non-null object
# POTW_PRESENT_IND                  14581 non-null object
# POTW_PROJECTED_IND                15122 non-null object
# DECENTRALIZED_ONLY_IND            27016 non-null object
# CITIES_TOWNS                      8350 non-null object
# dtypes: int64(4), object(55)
# memory usage: 12.2+ MB

# %%
df_merge = pandas.merge(df_flow, df_facility, how= 'inner', on= 'CWNS_NUMBER')

# %%
df_merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15359 entries, 0 to 15358
# Data columns (total 74 columns):
# CWNS_NUMBER                       15359 non-null int64
# EXIST_MUNICIPAL                   13534 non-null float64
# EXIST_INDUSTRIAL                  2157 non-null float64
# EXIST_INFILTRATION                941 non-null float64
# EXIST_TOTAL                       14613 non-null float64
# EXIST_WET_WEATHER_PEAK            1063 non-null float64
# PRES_MUNICIPAL                    13536 non-null float64
# PRES_INDUSTRIAL                   2191 non-null float64
# PRES_INFILTRATION                 598 non-null float64
# PRES_TOTAL                        14613 non-null float64
# PRES_WET_WEATHER_PEAK             680 non-null float64
# PROJ_MUNICIPAL                    14017 non-null float64
# PROJ_INDUSTRIAL                   2311 non-null float64
# PROJ_INFILTRATION                 621 non-null float64
# PROJ_TOTAL                        15151 non-null float64
# PROJ_WET_WEATHER_PEAK             751 non-null float64
# REGION                            15359 non-null int64
# STATE                             15359 non-null object
# PRIMARY_COUNTY                    15359 non-null object
# SECONDARY_COUNTIES                362 non-null object
# AUTHORITY                         15359 non-null object
# POINT_OF_CONTACT_NAME             5709 non-null object
# POINT_OF_CONTACT_STREET_1         6770 non-null object
# POINT_OF_CONTACT_STREET_2         1736 non-null object
# POINT_OF_CONTACT_CITY             6992 non-null object
# POINT_OF_CONTACT_STATE            15359 non-null object
# POINT_OF_CONTACT_ZIP              6779 non-null object
# POINT_OF_CONTACT_PHONE            6542 non-null object
# POINT_OF_CONTACT_FAX              2609 non-null object
# POINT_OF_CONTACT_EMAIL            2497 non-null object
# FACILITY_NAME                     15359 non-null object
# OWNER_TYPE                        15359 non-null object
# PRIMARY_WATERSHED_HUC             15359 non-null int64
# PRIMARY_WATERSHED_NAME            15359 non-null object
# SECONDARY_WATERSHEDS              6 non-null object
# PRIMARY_CONGRESSIONAL_DISTRICT    15358 non-null object
# SECONDARY_CONGRESSIONAL_DIST      250 non-null object
# NPDES_PERMIT_NUMBER               12230 non-null object
# PERMIT_TYPE                       12230 non-null object
# FACILITY_STREET_1                 14818 non-null object
# FACILITY_STREET_2                 3192 non-null object
# FACILITY_CITY                     14819 non-null object
# FACILITY_STATE                    14833 non-null object
# FACILITY_ZIP                      14708 non-null object
# SYSTEM_NAME                       1525 non-null object
# FACILITY_DESCRIPTION              1778 non-null object
# MILITARY_IND                      15359 non-null object
# TMDL_IND                          15359 non-null object
# SOURCE_WATER_PROTECTION_IND       15359 non-null object
# SMALL_COMMUNITY_EXCEPTION_IND     15359 non-null object
# PRES_FACILITY_TYPE                15122 non-null object
# PRES_FACILITY_OVERALL_TYPE        15122 non-null object
# PRES_TREATMENT_PLANT_TYPE         9510 non-null object
# PROJ_FACILITY_TYPE                15350 non-null object
# PROJ_FACILITY_OVERALL_TYPE        15350 non-null object
# PROJ_TREATMENT_PLANT_TYPE         9510 non-null object
# COORDINATE_TYPE                   14811 non-null object
# LOCATION_DESCRIPTION              13958 non-null object
# LATITUDE                          14811 non-null object
# LONGITUDE                         14811 non-null object
# HORIZONTAL_COORDINATE_DATUM       14671 non-null object
# HORIZONTAL_COLLECTION_METHOD      13853 non-null object
# SCALE                             3581 non-null object
# GEOGRAPHIC_LOCATION_SOURCE        14811 non-null object
# MEASUREMENT_DATE                  2534 non-null object
# TRIBE_IND                         15359 non-null object
# SPECIAL_PROGRAM_AREAS             496 non-null object
# FACILITY_ID                       15359 non-null int64
# REVIEW_STATUS                     15359 non-null object
# SMALL_COMMUNITY_IND               15359 non-null object
# POTW_PRESENT_IND                  14581 non-null object
# POTW_PROJECTED_IND                15121 non-null object
# DECENTRALIZED_ONLY_IND            15359 non-null object
# CITIES_TOWNS                      2721 non-null object
# dtypes: float64(15), int64(4), object(55)
# memory usage: 8.8+ MB

# %%
df_merge.head()
# Out:
#    CWNS_NUMBER  EXIST_MUNICIPAL  EXIST_INDUSTRIAL  EXIST_INFILTRATION  \
# 0   1000002001            0.060               NaN                 NaN
# 1   1000003001            2.500               0.3                 0.2
# 2   1000004001            4.700               NaN                 NaN
# 3   1000004002            1.510               NaN                 NaN
# 4   1000005001            0.017               NaN                 NaN
#
#    EXIST_TOTAL  EXIST_WET_WEATHER_PEAK  PRES_MUNICIPAL  PRES_INDUSTRIAL  \
# 0        0.060                     NaN           0.110              NaN
# 1        3.000                     NaN           7.600              NaN
# 2        4.700                     NaN           8.500              NaN
# 3        1.510                     NaN           1.950              NaN
# 4        0.017                   0.287           0.016              NaN
#
#    PRES_INFILTRATION  PRES_TOTAL               ...                 \
# 0                NaN       0.110               ...
# 1                NaN       7.600               ...
# 2                NaN       8.500               ...
# 3                NaN       1.950               ...
# 4                NaN       0.016               ...
#
#    MEASUREMENT_DATE  TRIBE_IND  SPECIAL_PROGRAM_AREAS  FACILITY_ID  \
# 0               NaN          N                    NaN      1239395
# 1               NaN          N                    NaN      1101826
# 2               NaN          N                    NaN      1101827
# 3               NaN          N                    NaN      1101828
# 4               NaN          N                    NaN      1101831
#
#       REVIEW_STATUS  SMALL_COMMUNITY_IND  POTW_PRESENT_IND POTW_PROJECTED_IND  \
# 0  Federal Accepted                    Y                 Y                  Y
# 1  Federal Accepted                    N                 Y                  Y
# 2  Federal Accepted                    N                 Y                  Y
# 3  Federal Accepted                    N                 Y                  Y
# 4  Federal Accepted                    Y                 Y                  Y
#
#   DECENTRALIZED_ONLY_IND                     CITIES_TOWNS
# 0                      N                              NaN
# 1                      N  Alabaster, Unincorporated areas
# 2                      N                              NaN
# 3                      N                              NaN
# 4                      N    Altoona, Unincorporated areas
#
# [5 rows x 74 columns]

# %%
df_data = df_merge.groupby('FACILITY_STATE').agg({'EXIST_TOTAL': np.sum,
                                               'EXIST_INDUSTRIAL': np.sum,
                                               'EXIST_MUNICIPAL': np.sum,
                                               'EXIST_INFILTRATION': np.sum})

# %%
df_data.dtypes
# Out:
# EXIST_TOTAL           float64
# EXIST_INDUSTRIAL      float64
# EXIST_INFILTRATION    float64
# EXIST_MUNICIPAL       float64
# dtype: object

# %%
#don't need this. just use reset_index below
#df_data['index'] = df_data.index

# %%
df_final_flow = df_data.reset_index()

# %%
df_final_flow
# Out:
#    FACILITY_STATE  EXIST_TOTAL  EXIST_INDUSTRIAL  EXIST_INFILTRATION  \
# 0              AK       37.886               NaN                 NaN
# 1              AL      412.251            19.205              17.520
# 2              AR      265.932               NaN                 NaN
# 3              AS        3.110               NaN               1.100
# 4              AZ      498.772             3.034               1.420
# 5              CA     3515.950           211.924               5.090
# 6              CO      372.378             2.380                 NaN
# 7              CT      388.009            64.544              44.476
# 8              DC      370.002               NaN                 NaN
# 9              DE      104.110            15.450                 NaN
# 10             FL     1560.995            24.410                 NaN
# 11             GA      767.345            88.979                 NaN
# 12             GU       17.030               NaN                 NaN
# 13             HI      137.686             8.000                 NaN
# 14             IA      380.349            43.152              35.846
# 15             ID      138.981            11.774               8.646
# 16             IL     2215.376           249.791               3.238
# 17             IN      961.356           145.047              24.071
# 18             KS      309.278            43.270              26.492
# 19             KY      422.816            11.509               8.095
# 20             LA      497.029             3.160               0.150
# 21             MA      756.757            50.041             138.900
# 22             MD      456.770            37.537               0.061
# 23             ME      135.990            16.350              14.017
# 24             MI     1364.277           291.540               7.520
# 25             MN      409.013            90.520                 NaN
# 26             MO      810.255            93.460              53.740
# 27             MS      263.057            27.058              11.673
# 28             MT       80.229             0.332               1.364
# 29             NC      679.113           167.896              39.166
# 30             ND       59.728             6.225                 NaN
# 31             NE      192.891            34.411                 NaN
# 32             NH       98.027             3.100                 NaN
# 33             NJ     1212.340           126.111              48.275
# 34             NM      184.113             5.160                 NaN
# 35             NV      274.469               NaN                 NaN
# 36             NY     2815.204           118.376             113.426
# 37             OH     1873.037           210.232              29.482
# 38             OK      357.442            11.425               1.000
# 39             OR      401.545            11.553              58.100
# 40             PA     1631.373           154.622               5.750
# 41             PR      232.590             0.060                 NaN
# 42             RI      132.200            42.000               1.000
# 43             SD       18.947             5.475                 NaN
# 44             TN      726.138            85.040              54.671
# 45             TX     1850.930           140.351                 NaN
# 46             UT      147.410            12.010               0.351
# 47             VA      739.583           120.747               3.900
# 48             VI        4.630               NaN                 NaN
# 49             VT       45.932             5.188               1.247
# 50             WA      662.014             4.697                 NaN
# 51             WI      649.604            85.035               4.082
# 52             WV      167.029             7.907               3.507
# 53             WY       52.002             1.582               0.808
#
#     EXIST_MUNICIPAL
# 0               NaN
# 1           374.566
# 2           265.911
# 3             2.010
# 4           275.259
# 5          3004.506
# 6            68.377
# 7           278.989
# 8           370.002
# 9            86.650
# 10          720.554
# 11          583.986
# 12           17.030
# 13          129.686
# 14          262.433
# 15          103.671
# 16         1962.347
# 17          524.773
# 18          239.511
# 19          253.106
# 20          493.518
# 21          433.754
# 22          407.953
# 23          105.363
# 24         1063.743
# 25          195.442
# 26          405.491
# 27          222.320
# 28           78.271
# 29          472.051
# 30           53.503
# 31          157.286
# 32           70.754
# 33         1037.954
# 34          154.153
# 35          271.484
# 36         2582.249
# 37         1632.543
# 38          343.957
# 39          331.892
# 40         1471.001
# 41          232.030
# 42           81.570
# 43           13.472
# 44          586.427
# 45         1664.574
# 46           28.354
# 47          463.536
# 48              NaN
# 49           39.497
# 50          470.573
# 51          348.400
# 52          155.609
# 53           49.612

# %%
df_sankey.dtypes
# Out:
# FACILITY_STATE     object
# waste_water       float64
# dtype: object

# %%
df_final = pandas.merge(df_final_flow, df_sankey, how= 'inner', on = 'FACILITY_STATE')

# %%
df_final
# Out:
#    FACILITY_STATE  EXIST_TOTAL  EXIST_INDUSTRIAL  EXIST_INFILTRATION  \
# 0              AK       37.886               NaN                 NaN
# 1              AL      412.251            19.205              17.520
# 2              AR      265.932               NaN                 NaN
# 3              AZ      498.772             3.034               1.420
# 4              CA     3515.950           211.924               5.090
# 5              CO      372.378             2.380                 NaN
# 6              CT      388.009            64.544              44.476
# 7              DE      104.110            15.450                 NaN
# 8              FL     1560.995            24.410                 NaN
# 9              GA      767.345            88.979                 NaN
# 10             HI      137.686             8.000                 NaN
# 11             IA      380.349            43.152              35.846
# 12             ID      138.981            11.774               8.646
# 13             IL     2215.376           249.791               3.238
# 14             IN      961.356           145.047              24.071
# 15             KS      309.278            43.270              26.492
# 16             KY      422.816            11.509               8.095
# 17             LA      497.029             3.160               0.150
# 18             MA      756.757            50.041             138.900
# 19             MD      456.770            37.537               0.061
# 20             ME      135.990            16.350              14.017
# 21             MI     1364.277           291.540               7.520
# 22             MN      409.013            90.520                 NaN
# 23             MO      810.255            93.460              53.740
# 24             MS      263.057            27.058              11.673
# 25             MT       80.229             0.332               1.364
# 26             NC      679.113           167.896              39.166
# 27             ND       59.728             6.225                 NaN
# 28             NE      192.891            34.411                 NaN
# 29             NH       98.027             3.100                 NaN
# 30             NJ     1212.340           126.111              48.275
# 31             NM      184.113             5.160                 NaN
# 32             NV      274.469               NaN                 NaN
# 33             NY     2815.204           118.376             113.426
# 34             OH     1873.037           210.232              29.482
# 35             OK      357.442            11.425               1.000
# 36             OR      401.545            11.553              58.100
# 37             PA     1631.373           154.622               5.750
# 38             RI      132.200            42.000               1.000
# 39             SD       18.947             5.475                 NaN
# 40             TN      726.138            85.040              54.671
# 41             TX     1850.930           140.351                 NaN
# 42             UT      147.410            12.010               0.351
# 43             VA      739.583           120.747               3.900
# 44             VT       45.932             5.188               1.247
# 45             WA      662.014             4.697                 NaN
# 46             WI      649.604            85.035               4.082
# 47             WV      167.029             7.907               3.507
# 48             WY       52.002             1.582               0.808
#
#     EXIST_MUNICIPAL  waste_water
# 0               NaN    69.744888
# 1           374.566   686.321488
# 2           265.911   292.393753
# 3           275.259   563.568726
# 4          3004.506  4716.181913
# 5            68.377   634.182624
# 6           278.989   369.795368
# 7            86.650    69.788494
# 8           720.554  1809.395071
# 9           583.986   933.831256
# 10          129.686   130.787528
# 11          262.433   298.622934
# 12          103.671   228.842007
# 13         1962.347  1362.130202
# 14          524.773   570.580403
# 15          239.511   163.002528
# 16          253.106   526.585367
# 17          493.518   281.853551
# 18          433.754   595.304309
# 19          407.953   706.149317
# 20          105.363    80.211366
# 21         1063.743   959.329694
# 22          195.442   423.398262
# 23          405.491   672.370055
# 24          222.320   304.215304
# 25           78.271    77.728572
# 26          472.051   746.905061
# 27           53.503    49.523175
# 28          157.286   170.833262
# 29           70.754    79.597050
# 30         1037.954   938.408814
# 31          154.153   124.399909
# 32          271.484   371.954311
# 33         2582.249  2099.119575
# 34         1632.543  1143.186116
# 35          343.957   540.070612
# 36          331.892   446.066819
# 37         1471.001  1313.808230
# 38           81.570    93.839393
# 39           13.472   100.456241
# 40          586.427   827.758385
# 41         1664.574  2649.138799
# 42           28.354   449.976239
# 43          463.536   594.490117
# 44           39.497    37.724875
# 45          470.573   791.846628
# 46          348.400   391.289240
# 47          155.609   166.636249
# 48           49.612    58.091731

# %%
plt.scatter(df_final['EXIST_TOTAL'], df_final['waste_water'])

# %%
plt.show()

# %%
df_final['Difference'] = df_final['EXIST_TOTAL'] - df_final['waste_water']

# %%
# (obs2 - obs1) / obs1
df_final['% change'] = (df_final['Difference']/ df_final['waste_water']) * 100

# %%
df_final
# Out:
#    FACILITY_STATE  EXIST_TOTAL  EXIST_INDUSTRIAL  EXIST_INFILTRATION  \
# 0              AK       37.886               NaN                 NaN
# 1              AL      412.251            19.205              17.520
# 2              AR      265.932               NaN                 NaN
# 3              AZ      498.772             3.034               1.420
# 4              CA     3515.950           211.924               5.090
# 5              CO      372.378             2.380                 NaN
# 6              CT      388.009            64.544              44.476
# 7              DE      104.110            15.450                 NaN
# 8              FL     1560.995            24.410                 NaN
# 9              GA      767.345            88.979                 NaN
# 10             HI      137.686             8.000                 NaN
# 11             IA      380.349            43.152              35.846
# 12             ID      138.981            11.774               8.646
# 13             IL     2215.376           249.791               3.238
# 14             IN      961.356           145.047              24.071
# 15             KS      309.278            43.270              26.492
# 16             KY      422.816            11.509               8.095
# 17             LA      497.029             3.160               0.150
# 18             MA      756.757            50.041             138.900
# 19             MD      456.770            37.537               0.061
# 20             ME      135.990            16.350              14.017
# 21             MI     1364.277           291.540               7.520
# 22             MN      409.013            90.520                 NaN
# 23             MO      810.255            93.460              53.740
# 24             MS      263.057            27.058              11.673
# 25             MT       80.229             0.332               1.364
# 26             NC      679.113           167.896              39.166
# 27             ND       59.728             6.225                 NaN
# 28             NE      192.891            34.411                 NaN
# 29             NH       98.027             3.100                 NaN
# 30             NJ     1212.340           126.111              48.275
# 31             NM      184.113             5.160                 NaN
# 32             NV      274.469               NaN                 NaN
# 33             NY     2815.204           118.376             113.426
# 34             OH     1873.037           210.232              29.482
# 35             OK      357.442            11.425               1.000
# 36             OR      401.545            11.553              58.100
# 37             PA     1631.373           154.622               5.750
# 38             RI      132.200            42.000               1.000
# 39             SD       18.947             5.475                 NaN
# 40             TN      726.138            85.040              54.671
# 41             TX     1850.930           140.351                 NaN
# 42             UT      147.410            12.010               0.351
# 43             VA      739.583           120.747               3.900
# 44             VT       45.932             5.188               1.247
# 45             WA      662.014             4.697                 NaN
# 46             WI      649.604            85.035               4.082
# 47             WV      167.029             7.907               3.507
# 48             WY       52.002             1.582               0.808
#
#     EXIST_MUNICIPAL  waste_water   Difference   % change
# 0               NaN    69.744888   -31.858888 -45.679173
# 1           374.566   686.321488  -274.070489 -39.933252
# 2           265.911   292.393753   -26.461753  -9.050040
# 3           275.259   563.568726   -64.796726 -11.497573
# 4          3004.506  4716.181913 -1200.231913 -25.449229
# 5            68.377   634.182624  -261.804624 -41.282213
# 6           278.989   369.795368    18.213631   4.925327
# 7            86.650    69.788494    34.321506  49.179319
# 8           720.554  1809.395071  -248.400071 -13.728349
# 9           583.986   933.831256  -166.486256 -17.828302
# 10          129.686   130.787528     6.898472   5.274564
# 11          262.433   298.622934    81.726066  27.367646
# 12          103.671   228.842007   -89.861007 -39.267706
# 13         1962.347  1362.130202   853.245798  62.640546
# 14          524.773   570.580403   390.775597  68.487385
# 15          239.511   163.002528   146.275472  89.738161
# 16          253.106   526.585367  -103.769367 -19.706086
# 17          493.518   281.853551   215.175449  76.342997
# 18          433.754   595.304309   161.452691  27.121035
# 19          407.953   706.149317  -249.379317 -35.315380
# 20          105.363    80.211366    55.778634  69.539563
# 21         1063.743   959.329694   404.947306  42.211485
# 22          195.442   423.398262   -14.385262  -3.397572
# 23          405.491   672.370055   137.884944  20.507300
# 24          222.320   304.215304   -41.158304 -13.529334
# 25           78.271    77.728572     2.500428   3.216872
# 26          472.051   746.905061   -67.792061  -9.076396
# 27           53.503    49.523175    10.204825  20.606160
# 28          157.286   170.833262    22.057738  12.911852
# 29           70.754    79.597050    18.429950  23.154062
# 30         1037.954   938.408814   273.931186  29.191029
# 31          154.153   124.399909    59.713091  48.000912
# 32          271.484   371.954311   -97.485311 -26.208948
# 33         2582.249  2099.119575   716.084425  34.113560
# 34         1632.543  1143.186116   729.850884  63.843575
# 35          343.957   540.070612  -182.628612 -33.815692
# 36          331.892   446.066819   -44.521819  -9.980975
# 37         1471.001  1313.808230   317.564770  24.171318
# 38           81.570    93.839393    38.360607  40.879001
# 39           13.472   100.456241   -81.509241 -81.139051
# 40          586.427   827.758385  -101.620385 -12.276576
# 41         1664.574  2649.138799  -798.208799 -30.130879
# 42           28.354   449.976239  -302.566239 -67.240492
# 43          463.536   594.490117   145.092883  24.406273
# 44           39.497    37.724875     8.207125  21.755209
# 45          470.573   791.846628  -129.832628 -16.396184
# 46          348.400   391.289240   258.314760  66.016321
# 47          155.609   166.636249     0.392751   0.235694
# 48           49.612    58.091731    -6.089731 -10.482956

# %%
titles = df_final['FACILITY_STATE']
bar_heights = df_final['% change']
bar_positions = np.arange(len(bar_heights))

plt.figure(figsize = (25,15))
plt.bar(bar_positions, bar_heights, .5)
plt.xticks(bar_positions, titles, rotation = 90)
plt.show()

# %%
fig, ax = plt.subplots()
graph = ax.bar(bar)
